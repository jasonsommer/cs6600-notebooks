# %% [markdown]
# # 01.B: Organizing data into  Series and DataFrames with Pandas
#
# Pandas is another essential package for data analysis and machine learning. It comes with two main data structures: Series and DataFrame. A Series is like a dictionary with keys (also called indexes) and values. A DataFrame represents tabular data with one or more columns.
#
# To use pandas, we first need to import it. Let's also import NumPy.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# We can now create series and dataframes.
#
# ## Series
# A series is a one-dimensional narray with axis labels (or indexes).
#
# ### Creating a series
# We can create a series by providing an array of values.

# %%
s1 = pd.Series([10,20,30,40,50])
print(s1)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %% [markdown]
# Since we did not provide indexes for our data, numeric zero-based indexes (much like those for arrays) will be automatically provided.
#
# We can also create a series by providing custom indexes.

# %%
s2 = pd.Series([1,2,3,4,5], index=['a','b','c','d','e'])
print(s2)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %% [markdown]
# Notice that indexes are not required to be unique. For example, we can create a Series with duplicate indexes.

# %%
s3 = pd.Series([1,2,3,4,5], index=['a','b','b','c','c']) 
print(s3)
# Out:
# a    1
# b    2
# b    3
# c    4
# c    5
# dtype: int64

# %% [markdown]
# We can create a series from NumPy arrays.

# %%
snp = pd.Series(np.arange(2, 11, 2), index=['A','B','C','D','F']) 
print(snp)
# Out:
# A     2
# B     4
# C     6
# D     8
# F    10
# dtype: int64

# %% [markdown]
# And indexes could be ranges.

# %%
s4 = pd.Series(np.arange(2, 11, 2), index=np.arange(1, 6)) 
print(s4)
# Out:
# 1     2
# 2     4
# 3     6
# 4     8
# 5    10
# dtype: int64

# %% [markdown]
# ### Accessing elements in a series
#
# We can use the indexes to extract and/or slice elements within a series. For example, given the series `s1`:

# %%
s1
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %% [markdown]
# Here is the element at index 0:

# %%
s1[0]
# Out:
# 10

# %% [markdown]
# and the elements at indexes 2 and 3:

# %%
s1[[2,3]]
# Out:
# 2    30
# 3    40
# dtype: int64

# %% [markdown]
# or at the index range from 2 up to but not equal to 4

# %%
s1[2:4]
# Out:
# 2    30
# 3    40
# dtype: int64

# %% [markdown]
# And given the series `s2`:

# %%
s2
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %% [markdown]
# Here is the element at index 'c':

# %%
s2['c']
# Out:
# 3

# %% [markdown]
# and here are the elements from index 'b' to index 'd'

# %%
s2['b':'d']
# Out:
# b    2
# c    3
# d    4
# dtype: int64

# %% [markdown]
# And for a series with duplicate indexes such as:

# %%
s3
# Out:
# a    1
# b    2
# b    3
# c    4
# c    5
# dtype: int64

# %% [markdown]
# Using a duplicate index returns a series of all the elements with that index.

# %%
s3['b']
# Out:
# b    2
# b    3
# dtype: int64

# %% [markdown]
# The above use of indexes is the same as using `.loc[]` with indexes between `[` and `]`. That is

# %%
print(snp['A':'D'])
print(s3['b'])
# Out:
# A    2
# B    4
# C    6
# D    8
# dtype: int64
# b    2
# b    3
# dtype: int64

# %% [markdown]
# is the same as:

# %%
print(snp.loc['A':'D'])
print(s3.loc['b'])
# Out:
# A    2
# B    4
# C    6
# D    8
# dtype: int64
# b    2
# b    3
# dtype: int64

# %% [markdown]
# But sometimes we want to use the position of the index rather than its actual value to access elements within a series. We can use `.iloc[]` with zero-based numeric indexes positions between `[` and `]`. The position 0 means the first index. For example, given the Series:

# %%
snp
# Out:
# A     2
# B     4
# C     6
# D     8
# F    10
# dtype: int64

# %% [markdown]
# We can access its first element:

# %%
snp.iloc[0]
# Out:
# 2

# %% [markdown]
# And its last element:

# %%
snp.iloc[snp.size - 1]
# Out:
# 10

# %% [markdown]
# With `.iloc`, we can index and slice a series in exactly the same way we did in a one-dimensional NumPy array. Here is, for example, how you select every other element in a Series.

# %%
snp.iloc[0::2]
# Out:
# A     2
# C     6
# F    10
# dtype: int64

# %% [markdown]
# And speaking of NumPy, we can extract the values of a series as a NumPy array.

# %%
snp.values
# Out:
# array([ 2,  4,  6,  8, 10])

# %% [markdown]
# We can also extract its indexes as an array also:

# %%
snp.index
# Out:
# Index(['A', 'B', 'C', 'D', 'F'], dtype='object')

# %% [markdown]
# ## DataFrames
# A data frame is a two-dimensional table with columns and rows. You can think of each column on a DataFrame as a series sharing the same indexes with the other columns. Each column has a name that can be used to access it.
#
# ### Creating DataFrames
# The easiest way to create a DataFrame is by using a dictionary of arrays. The keys of this dictionary will become column names. Here is a DataFrame with 4 by 9 multiplication table.

# %%
mtable = pd.DataFrame({
    'byOne': [1,2, 3, 4, 5, 6, 7, 8, 9],
    'byTwo': [2, 4, 6, 8, 10, 12, 14, 16, 18],
    'byThree': [3, 6, 9, 12, 15, 18, 21, 24, 27],
    'byFour': [4, 8, 12, 16, 20, 24, 28, 32, 36]
})

mtable
# Out:
#    byOne  byTwo  byThree  byFour
# 0      1      2        3       4
# 1      2      4        6       8
# 2      3      6        9      12
# 3      4      8       12      16
# 4      5     10       15      20
# 5      6     12       18      24
# 6      7     14       21      28
# 7      8     16       24      32
# 8      9     18       27      36

# %% [markdown]
# Since we did not provide indexes, Pandas will create zero-based numeric indexes for us, just like it does for a Series.
#
# We can use NumPy arrays to create the same table:

# %%
mtable = pd.DataFrame({
    'byOne': np.arange(1, 10),
    'byTwo': 2 * np.arange(1, 10),
    'byThree': 3 * np.arange(1, 10),
    'byFour': 4 * np.arange(1, 10)
})

print(mtable)
# Out:
#    byOne  byTwo  byThree  byFour
# 0      1      2        3       4
# 1      2      4        6       8
# 2      3      6        9      12
# 3      4      8       12      16
# 4      5     10       15      20
# 5      6     12       18      24
# 6      7     14       21      28
# 7      8     16       24      32
# 8      9     18       27      36

# %% [markdown]
# We can create a DataFrame from a two-dimensional array. Given an array,

# %%
table = np.array([
    np.arange(1, 10),
    2 * np.arange(1, 10),
    3 * np.arange(1, 10),
    4 * np.arange(1, 10)
]).T

print(table)
# Out:
# [[ 1  2  3  4]
#  [ 2  4  6  8]
#  [ 3  6  9 12]
#  [ 4  8 12 16]
#  [ 5 10 15 20]
#  [ 6 12 18 24]
#  [ 7 14 21 28]
#  [ 8 16 24 32]
#  [ 9 18 27 36]]

# %% [markdown]
# we can create a DataFrame from it.

# %%
mtable = pd.DataFrame(table)

mtable
# Out:
#    0   1   2   3
# 0  1   2   3   4
# 1  2   4   6   8
# 2  3   6   9  12
# 3  4   8  12  16
# 4  5  10  15  20
# 5  6  12  18  24
# 6  7  14  21  28
# 7  8  16  24  32
# 8  9  18  27  36

# %% [markdown]
# Since we did not provide column names or indexes, Pandas provided numeric zero-based column names and indexes for us. We can rename these columns by providing custom names for it after it was created.

# %%
mtable.columns= ['A', 'B', 'C', 'D']
mtable
# Out:
#    A   B   C   D
# 0  1   2   3   4
# 1  2   4   6   8
# 2  3   6   9  12
# 3  4   8  12  16
# 4  5  10  15  20
# 5  6  12  18  24
# 6  7  14  21  28
# 7  8  16  24  32
# 8  9  18  27  36

# %% [markdown]
# We can provide the column names at the time of creating the DataFrame.

# %%
mt = pd.DataFrame(table, columns=['byOne', 'byTwo', 'byThree', 'byFour'])

mt
# Out:
#    byOne  byTwo  byThree  byFour
# 0      1      2        3       4
# 1      2      4        6       8
# 2      3      6        9      12
# 3      4      8       12      16
# 4      5     10       15      20
# 5      6     12       18      24
# 6      7     14       21      28
# 7      8     16       24      32
# 8      9     18       27      36

# %% [markdown]
# We can also provide custom indexes.

# %%
mt = pd.DataFrame(table, 
                  columns=['byOne', 'byTwo', 'byThree', 'byFour'],
                  index=['x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8', 'x9'])

mt
# Out:
#     byOne  byTwo  byThree  byFour
# x1      1      2        3       4
# x2      2      4        6       8
# x3      3      6        9      12
# x4      4      8       12      16
# x5      5     10       15      20
# x6      6     12       18      24
# x7      7     14       21      28
# x8      8     16       24      32
# x9      9     18       27      36

# %% [markdown]
# We can convert the contents of a DataFrame to a NumPy array:

# %%
mt.values
# Out:
# array([[ 1,  2,  3,  4],
#        [ 2,  4,  6,  8],
#        [ 3,  6,  9, 12],
#        [ 4,  8, 12, 16],
#        [ 5, 10, 15, 20],
#        [ 6, 12, 18, 24],
#        [ 7, 14, 21, 28],
#        [ 8, 16, 24, 32],
#        [ 9, 18, 27, 36]])

# %% [markdown]
# We can get its column names:

# %%
mt.columns
# Out:
# Index(['byOne', 'byTwo', 'byThree', 'byFour'], dtype='object')

# %% [markdown]
# and its indexes:

# %%
mt.index
# Out:
# Index(['x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8', 'x9'], dtype='object')

# %% [markdown]
# ### Adding new columns and rows to an existing DataFrame
# Given the DataFrame:

# %%
mt
# Out:
#     byOne  byTwo  byThree  byFour
# x1      1      2        3       4
# x2      2      4        6       8
# x3      3      6        9      12
# x4      4      8       12      16
# x5      5     10       15      20
# x6      6     12       18      24
# x7      7     14       21      28
# x8      8     16       24      32
# x9      9     18       27      36

# %% [markdown]
# We can add a new column like this:

# %%
mt['byFive'] = 5 * np.arange(1, 10)

mt
# Out:
#     byOne  byTwo  byThree  byFour  byFive
# x1      1      2        3       4       5
# x2      2      4        6       8      10
# x3      3      6        9      12      15
# x4      4      8       12      16      20
# x5      5     10       15      20      25
# x6      6     12       18      24      30
# x7      7     14       21      28      35
# x8      8     16       24      32      40
# x9      9     18       27      36      45

# %% [markdown]
# And using the `.loc`, we can add a new row like this:

# %%
mt.loc['x10'] = 10 * np.arange(1, 6)
mt
# Out:
#      byOne  byTwo  byThree  byFour  byFive
# x1       1      2        3       4       5
# x2       2      4        6       8      10
# x3       3      6        9      12      15
# x4       4      8       12      16      20
# x5       5     10       15      20      25
# x6       6     12       18      24      30
# x7       7     14       21      28      35
# x8       8     16       24      32      40
# x9       9     18       27      36      45
# x10     10     20       30      40      50

# %% [markdown]
# ### Dropping a column or a row from a DataFrame
# We can use the `drop` method to remove a column from a DataFrame. Let's remove the column `byFive` we added above:

# %%
mt.drop(['byFive'], axis=1)
# Out:
#      byOne  byTwo  byThree  byFour
# x1       1      2        3       4
# x2       2      4        6       8
# x3       3      6        9      12
# x4       4      8       12      16
# x5       5     10       15      20
# x6       6     12       18      24
# x7       7     14       21      28
# x8       8     16       24      32
# x9       9     18       27      36
# x10     10     20       30      40

# %% [markdown]
# Here `axis=1` refers to columns. To drop a row we use `axis=0` and provide a index instead of a column name.

# %%
mt.drop(['x10'], axis=0)
# Out:
#     byOne  byTwo  byThree  byFour  byFive
# x1      1      2        3       4       5
# x2      2      4        6       8      10
# x3      3      6        9      12      15
# x4      4      8       12      16      20
# x5      5     10       15      20      25
# x6      6     12       18      24      30
# x7      7     14       21      28      35
# x8      8     16       24      32      40
# x9      9     18       27      36      45

# %% [markdown]
# ### DataFrame indexing and slicing
#
# We can use the column names and indexes to access individual cells.

# %%
mt['byTwo']['x5']
# Out:
# 10

# %% [markdown]
# To extract a single column, use its name:

# %%
mt['byThree']
# Out:
# x1      3
# x2      6
# x3      9
# x4     12
# x5     15
# x6     18
# x7     21
# x8     24
# x9     27
# x10    30
# Name: byThree, dtype: int64

# %% [markdown]
# And use an array of column names to extract multiple columns

# %%
mt[['byTwo', 'byFour']]
# Out:
#      byTwo  byFour
# x1       2       4
# x2       4       8
# x3       6      12
# x4       8      16
# x5      10      20
# x6      12      24
# x7      14      28
# x8      16      32
# x9      18      36
# x10     20      40

# %% [markdown]
# Use `.loc` to access a specific row using its index:

# %%
mt.loc['x6']
# Out:
# byOne       6
# byTwo      12
# byThree    18
# byFour     24
# byFive     30
# Name: x6, dtype: int64

# %% [markdown]
# Similarly we can extract rows using their index positions using `.iloc[]`. We can, for example extract the first row using the its index position `0` (the index itself is `x1`).

# %%
mt.iloc[0]
# Out:
# byOne      1
# byTwo      2
# byThree    3
# byFour     4
# byFive     5
# Name: x1, dtype: int64

# %% [markdown]
# We can also use `.iloc` to access certain columns and rows based on their positions, much like the indexing and slicing of a two-dimensional NumPy array. Here is the whole DataFrame:

# %%
mt.iloc[:, :]
# Out:
#      byOne  byTwo  byThree  byFour  byFive
# x1       1      2        3       4       5
# x2       2      4        6       8      10
# x3       3      6        9      12      15
# x4       4      8       12      16      20
# x5       5     10       15      20      25
# x6       6     12       18      24      30
# x7       7     14       21      28      35
# x8       8     16       24      32      40
# x9       9     18       27      36      45
# x10     10     20       30      40      50

# %% [markdown]
# In the `[:, :]` expression, the first `:` refers to all rows and the second `:` refers to all columns.
#
# Here is a slice from the third(position 2) row to the sixth (position 5) and from the second column (position 1) to the fifth column(position 4).

# %%
mt.iloc[2:5, 1:4]
# Out:
#     byTwo  byThree  byFour
# x3      6        9      12
# x4      8       12      16
# x5     10       15      20

# %% [markdown]
# And here is every other column and row.

# %%
mt.iloc[::2, ::2]
# Out:
#     byOne  byThree  byFive
# x1      1        3       5
# x3      3        9      15
# x5      5       15      25
# x7      7       21      35
# x9      9       27      45

# %% [markdown]
# Finally we can use the methods `head` and `tail` to display the first couple of rows at the top or the bottom of a DataFrame. This is useful for exploring large dataframes.

# %%
print(mt.head())
print(mt.head(6))

print(mt.tail())
print(mt.tail(7))
# Out:
#     byOne  byTwo  byThree  byFour  byFive
# x1      1      2        3       4       5
# x2      2      4        6       8      10
# x3      3      6        9      12      15
# x4      4      8       12      16      20
# x5      5     10       15      20      25
#     byOne  byTwo  byThree  byFour  byFive
# x1      1      2        3       4       5
# x2      2      4        6       8      10
# x3      3      6        9      12      15
# x4      4      8       12      16      20
# x5      5     10       15      20      25
# x6      6     12       18      24      30
#      byOne  byTwo  byThree  byFour  byFive
# x6       6     12       18      24      30
# x7       7     14       21      28      35
# x8       8     16       24      32      40
# x9       9     18       27      36      45
# x10     10     20       30      40      50
#      byOne  byTwo  byThree  byFour  byFive
# x4       4      8       12      16      20
# x5       5     10       15      20      25
# x6       6     12       18      24      30
# x7       7     14       21      28      35
# x8       8     16       24      32      40
# x9       9     18       27      36      45
# x10     10     20       30      40      50

# %% [markdown]
# ### Summarizing dataframes
# Given the following 50 by 10 DataFrame:

# %%
data = pd.DataFrame(np.random.randn(50,10), columns=list('ABCDEFGHIJ'))

# %%
data
# Out:
#            A         B         C         D         E         F         G  \
# 0   0.426313 -0.787721 -1.224338  0.893432 -1.352372  0.388699  0.780838
# 1  -0.992258  0.690064 -0.049687 -0.162374  1.182594 -0.384349 -0.860794
# 2  -1.600852 -0.750423 -1.054071 -0.008069 -0.482367  0.103176 -0.087262
# 3  -2.085142  0.582091  1.393866 -0.736851 -0.746285  0.592250 -0.010729
# 4  -1.273573 -0.735513  0.278379  1.275783  0.566976  0.110183  1.615711
# 5   0.377197  0.268434  0.402560  0.817262  0.702980  0.573296  0.458199
# 6   1.706675  0.089115  1.272565  2.107148 -0.816521  1.192772 -0.296606
# 7   0.036817  1.554621  0.788182 -0.646296 -0.419567  1.282313  0.876022
# 8  -0.895977  0.339033  0.050729 -0.533551  2.379354 -0.689652 -1.285117
# 9   0.421808  1.092169 -0.221153 -1.146687  0.036680 -0.241575 -1.126784
# 10 -0.290275  1.964764 -1.155740 -0.358058 -2.717593  0.480040 -0.610234
# 11 -0.151901 -1.257711  0.136678  1.156996 -0.296106 -0.758877  0.634862
# 12 -0.307682 -0.383570 -0.378537 -0.092785  1.776542 -0.281854 -0.863668
# 13  0.011341  0.964874 -0.260649  0.477133 -0.077941  0.048789  1.929163
# 14  0.782087  0.341843  2.155281  1.461825 -1.625138  1.990985 -0.929342
# 15  0.893147 -0.769879  0.021840  1.236838 -1.387989  1.340343 -0.220754
# 16  0.875488  0.340257  0.952013  1.347256  0.071229  0.007190  0.808689
# 17  1.034543  0.228079  0.352166  0.017243 -0.240124  2.315286  0.239775
# 18  1.258004  0.619982 -0.066919  0.846771 -0.535695  0.881425 -0.562133
# 19  0.485702 -0.008350  1.372400  1.214669  0.633774  0.761378 -0.502777
# 20  0.097214  1.220410 -0.376632 -0.970849 -0.317778 -0.236042  0.928106
# 21  1.037622  0.000379 -1.345190 -0.824340 -0.765386 -1.232404  0.646209
# 22  0.291899 -0.584251  0.005901 -0.599625 -0.248581  0.424971  0.046275
# 23 -1.512106 -1.188032  0.866016 -0.210163  1.945755  0.151333  0.160778
# 24  0.872465 -0.875142 -0.806504  0.363766 -0.600316 -0.496440  0.282859
# 25  2.853262  0.179320  1.311330 -0.973306 -0.960157  1.317074 -1.547584
# 26  0.860503  2.228581 -0.157448  1.225058  0.154353  0.426908 -0.510228
# 27 -1.114358 -1.708112 -1.510447  0.555755  0.081503  0.819431 -0.063133
# 28  0.901547  0.411391 -0.089698 -1.324709 -0.312332  0.134611  1.233098
# 29 -0.487626 -1.103681  0.515218 -1.616295 -0.155946 -0.708117  1.005927
# 30  1.235540  1.196118  0.362801  0.894863 -0.384782 -0.498329  0.985835
# 31  0.077762 -0.181839  0.467956 -1.809766  1.689064  0.776785  0.167322
# 32 -0.632907 -3.285639  1.030422 -1.303500  0.843170 -0.793729  0.863666
# 33 -0.442826 -0.107227  1.223596  0.987649  0.172307  0.028545  0.422195
# 34 -0.689227  0.476809 -1.624731 -0.528724  0.056395 -0.009303 -0.112903
# 35  0.325957 -1.299911 -1.413615  2.135799 -0.192028 -0.826699 -1.183908
# 36 -0.278111  0.851859 -0.242392  0.822918  0.714814  1.411720 -0.732998
# 37 -0.103178  0.215423 -0.190171 -0.146015  1.130946 -0.407226  1.424011
# 38 -0.761906 -0.891034 -0.231613 -0.976902 -1.159567  0.107267  0.400133
# 39  0.884666  1.654871  0.017879 -0.068437  1.077554  0.327493 -0.680256
# 40  1.829465  1.084604  0.922062  1.163527  0.036508  0.487104 -0.247985
# 41  0.212487 -1.250164 -0.681394 -0.372703  0.218476  1.116526 -0.648365
# 42  0.305061 -1.384498  0.244176 -1.441362 -0.690596  0.163163 -0.994253
# 43  1.200701 -0.778513  0.892624  0.002695  0.843146 -0.258137 -0.355217
# 44 -0.086568 -0.098533  1.395970  0.035968 -0.096236 -2.201730 -0.750337
# 45 -1.029298 -0.244062  1.596040 -1.127986  1.407054  0.322942  0.067546
# 46 -0.456373  0.816332 -0.188480 -0.253740 -0.851245 -0.051668  1.574738
# 47 -0.343770  1.010273  0.360144 -0.952976 -0.020469  1.052827 -0.700469
# 48 -0.088836  0.733567  0.229747  0.594545  0.262723 -1.804256  1.432011
# 49 -0.319460  3.072399  0.903802 -0.900260 -0.376309  0.217875 -0.135733
#
#            H         I         J
# 0   0.161799  0.762249  0.935126
# 1  -1.303309 -0.247550  1.271908
# 2   0.619026 -0.883828  0.714544
# 3  -0.280606 -1.472615 -1.050276
# 4   0.547422  2.623677 -0.718434
# 5  -1.483077 -0.348366 -0.310876
# 6  -1.576477  0.065436  0.676060
# 7   0.843546  1.373736 -0.690190
# 8  -1.707093 -0.252063  0.169974
# 9   0.373656 -0.261116  0.531397
# 10  0.651889 -0.687009  0.333348
# 11  0.171054 -0.182157  0.527988
# 12 -1.042435  0.368005  0.214811
# 13  0.333347 -0.061435  0.072078
# 14 -0.476557 -1.113711 -1.139545
# 15  1.349173  0.059855 -0.141848
# 16 -1.200442  0.197725 -0.938434
# 17  0.856701 -0.116594  0.548419
# 18 -0.704400  1.889399  0.441985
# 19 -0.335557  1.072450  0.439272
# 20  0.017962 -0.812085 -1.173359
# 21 -1.504419  0.053029  1.720978
# 22  0.913696 -0.727702 -0.855709
# 23  0.987361 -0.278926  0.242451
# 24 -0.510848 -0.518429 -1.210196
# 25 -0.208042 -1.967565 -1.118693
# 26 -0.427345 -0.323164 -2.395816
# 27  1.328729 -2.363694 -0.334631
# 28 -0.808057 -0.200995 -0.021629
# 29 -0.264734  0.854760  1.101665
# 30  0.138136  0.997780 -0.777981
# 31  0.655176 -0.604080  0.174869
# 32  0.002331  1.401397 -0.666460
# 33 -0.376240 -1.486713  1.602888
# 34 -2.597858 -0.189222 -0.389867
# 35  0.428840 -0.628976  1.158286
# 36  1.727941  3.172556 -0.793473
# 37 -0.202430  0.946483  1.860508
# 38  0.618269 -1.399516  0.967657
# 39 -1.353163 -0.687604 -0.076833
# 40  0.174588  1.163103 -1.053624
# 41 -1.395959  0.613038  0.110745
# 42 -1.226895 -1.371310 -0.458074
# 43 -0.614838  1.170115 -0.212650
# 44  0.708286 -1.372964  2.196478
# 45  0.735212  0.133300  0.891856
# 46  0.789795 -0.049830  0.060698
# 47 -0.554859 -1.617304 -0.066278
# 48 -1.226823  1.224584 -1.079608
# 49  0.836101 -1.123775  0.240918

# %% [markdown]
# We can statistically summarize it like this:

# %%
data.describe()
# Out:
#                A          B          C          D          E          F  \
# count  50.000000  50.000000  50.000000  50.000000  50.000000  50.000000
# mean    0.107021   0.091077   0.165059   0.030971   0.003089   0.189486
# std     0.952063   1.129493   0.879518   0.999614   0.963624   0.865338
# min    -2.085142  -3.285639  -1.624731  -1.809766  -2.717593  -2.201730
# 25%    -0.452986  -0.765015  -0.239697  -0.802468  -0.522363  -0.275924
# 50%     0.057290   0.197372   0.093704  -0.080611  -0.087088   0.142972
# 75%     0.869474   0.795641   0.885972   0.881767   0.617075   0.719096
# max     2.853262   3.072399   2.155281   2.135799   2.379354   2.315286
#
#                G          H          I          J
# count  50.000000  50.000000  50.000000  50.000000
# mean    0.059288  -0.148249  -0.064152   0.030649
# std     0.851459   0.949466   1.129998   0.932004
# min    -1.547584  -2.597858  -2.363694  -2.395816
# 25%    -0.638832  -0.782142  -0.717678  -0.711373
# 50%    -0.036931  -0.100050  -0.195109   0.066388
# 75%     0.747181   0.643673   0.724946   0.544164
# max     1.929163   1.727941   3.172556   2.196478

# %% [markdown]
# We can also get the means of each column:

# %%
data.mean()
# Out:
# A    0.107021
# B    0.091077
# C    0.165059
# D    0.030971
# E    0.003089
# F    0.189486
# G    0.059288
# H   -0.148249
# I   -0.064152
# J    0.030649
# dtype: float64

# %% [markdown]
# and the variances of each column:

# %%
data.var()
# Out:
# A    0.906424
# B    1.275755
# C    0.773552
# D    0.999229
# E    0.928570
# F    0.748811
# G    0.724983
# H    0.901486
# I    1.276895
# J    0.868631
# dtype: float64

# %% [markdown]
# and the standard deviations of each column:

# %%
data.std()
# Out:
# A    0.952063
# B    1.129493
# C    0.879518
# D    0.999614
# E    0.963624
# F    0.865338
# G    0.851459
# H    0.949466
# I    1.129998
# J    0.932004
# dtype: float64

# %% [markdown]
# ## Transposing DataFrames
# We can transpose a DataFrame by making columns rows and rows columns. That means also reversing columns and indexes.

# %%
data.transpose()
# Out:
#          0         1         2         3         4         5         6   \
# A  0.426313 -0.992258 -1.600852 -2.085142 -1.273573  0.377197  1.706675
# B -0.787721  0.690064 -0.750423  0.582091 -0.735513  0.268434  0.089115
# C -1.224338 -0.049687 -1.054071  1.393866  0.278379  0.402560  1.272565
# D  0.893432 -0.162374 -0.008069 -0.736851  1.275783  0.817262  2.107148
# E -1.352372  1.182594 -0.482367 -0.746285  0.566976  0.702980 -0.816521
# F  0.388699 -0.384349  0.103176  0.592250  0.110183  0.573296  1.192772
# G  0.780838 -0.860794 -0.087262 -0.010729  1.615711  0.458199 -0.296606
# H  0.161799 -1.303309  0.619026 -0.280606  0.547422 -1.483077 -1.576477
# I  0.762249 -0.247550 -0.883828 -1.472615  2.623677 -0.348366  0.065436
# J  0.935126  1.271908  0.714544 -1.050276 -0.718434 -0.310876  0.676060
#
#          7         8         9   ...        40        41        42        43  \
# A  0.036817 -0.895977  0.421808  ...  1.829465  0.212487  0.305061  1.200701
# B  1.554621  0.339033  1.092169  ...  1.084604 -1.250164 -1.384498 -0.778513
# C  0.788182  0.050729 -0.221153  ...  0.922062 -0.681394  0.244176  0.892624
# D -0.646296 -0.533551 -1.146687  ...  1.163527 -0.372703 -1.441362  0.002695
# E -0.419567  2.379354  0.036680  ...  0.036508  0.218476 -0.690596  0.843146
# F  1.282313 -0.689652 -0.241575  ...  0.487104  1.116526  0.163163 -0.258137
# G  0.876022 -1.285117 -1.126784  ... -0.247985 -0.648365 -0.994253 -0.355217
# H  0.843546 -1.707093  0.373656  ...  0.174588 -1.395959 -1.226895 -0.614838
# I  1.373736 -0.252063 -0.261116  ...  1.163103  0.613038 -1.371310  1.170115
# J -0.690190  0.169974  0.531397  ... -1.053624  0.110745 -0.458074 -0.212650
#
#          44        45        46        47        48        49
# A -0.086568 -1.029298 -0.456373 -0.343770 -0.088836 -0.319460
# B -0.098533 -0.244062  0.816332  1.010273  0.733567  3.072399
# C  1.395970  1.596040 -0.188480  0.360144  0.229747  0.903802
# D  0.035968 -1.127986 -0.253740 -0.952976  0.594545 -0.900260
# E -0.096236  1.407054 -0.851245 -0.020469  0.262723 -0.376309
# F -2.201730  0.322942 -0.051668  1.052827 -1.804256  0.217875
# G -0.750337  0.067546  1.574738 -0.700469  1.432011 -0.135733
# H  0.708286  0.735212  0.789795 -0.554859 -1.226823  0.836101
# I -1.372964  0.133300 -0.049830 -1.617304  1.224584 -1.123775
# J  2.196478  0.891856  0.060698 -0.066278 -1.079608  0.240918
#
# [10 rows x 50 columns]

# %% [markdown]
# which is the same as:

# %%
data.T
# Out:
#          0         1         2         3         4         5         6   \
# A  0.426313 -0.992258 -1.600852 -2.085142 -1.273573  0.377197  1.706675
# B -0.787721  0.690064 -0.750423  0.582091 -0.735513  0.268434  0.089115
# C -1.224338 -0.049687 -1.054071  1.393866  0.278379  0.402560  1.272565
# D  0.893432 -0.162374 -0.008069 -0.736851  1.275783  0.817262  2.107148
# E -1.352372  1.182594 -0.482367 -0.746285  0.566976  0.702980 -0.816521
# F  0.388699 -0.384349  0.103176  0.592250  0.110183  0.573296  1.192772
# G  0.780838 -0.860794 -0.087262 -0.010729  1.615711  0.458199 -0.296606
# H  0.161799 -1.303309  0.619026 -0.280606  0.547422 -1.483077 -1.576477
# I  0.762249 -0.247550 -0.883828 -1.472615  2.623677 -0.348366  0.065436
# J  0.935126  1.271908  0.714544 -1.050276 -0.718434 -0.310876  0.676060
#
#          7         8         9   ...        40        41        42        43  \
# A  0.036817 -0.895977  0.421808  ...  1.829465  0.212487  0.305061  1.200701
# B  1.554621  0.339033  1.092169  ...  1.084604 -1.250164 -1.384498 -0.778513
# C  0.788182  0.050729 -0.221153  ...  0.922062 -0.681394  0.244176  0.892624
# D -0.646296 -0.533551 -1.146687  ...  1.163527 -0.372703 -1.441362  0.002695
# E -0.419567  2.379354  0.036680  ...  0.036508  0.218476 -0.690596  0.843146
# F  1.282313 -0.689652 -0.241575  ...  0.487104  1.116526  0.163163 -0.258137
# G  0.876022 -1.285117 -1.126784  ... -0.247985 -0.648365 -0.994253 -0.355217
# H  0.843546 -1.707093  0.373656  ...  0.174588 -1.395959 -1.226895 -0.614838
# I  1.373736 -0.252063 -0.261116  ...  1.163103  0.613038 -1.371310  1.170115
# J -0.690190  0.169974  0.531397  ... -1.053624  0.110745 -0.458074 -0.212650
#
#          44        45        46        47        48        49
# A -0.086568 -1.029298 -0.456373 -0.343770 -0.088836 -0.319460
# B -0.098533 -0.244062  0.816332  1.010273  0.733567  3.072399
# C  1.395970  1.596040 -0.188480  0.360144  0.229747  0.903802
# D  0.035968 -1.127986 -0.253740 -0.952976  0.594545 -0.900260
# E -0.096236  1.407054 -0.851245 -0.020469  0.262723 -0.376309
# F -2.201730  0.322942 -0.051668  1.052827 -1.804256  0.217875
# G -0.750337  0.067546  1.574738 -0.700469  1.432011 -0.135733
# H  0.708286  0.735212  0.789795 -0.554859 -1.226823  0.836101
# I -1.372964  0.133300 -0.049830 -1.617304  1.224584 -1.123775
# J  2.196478  0.891856  0.060698 -0.066278 -1.079608  0.240918
#
# [10 rows x 50 columns]

# %% [markdown]
# ### Sorting a DataFrame
#
# We can sort indexes, column names, or the values of a DataFrame. For example, the following sorts the indexes (`axis=0`) of the DataFrame in an ascending order:

# %%
mt.sort_index(axis=0)
# Out:
#      byOne  byTwo  byThree  byFour  byFive
# x1       1      2        3       4       5
# x10     10     20       30      40      50
# x2       2      4        6       8      10
# x3       3      6        9      12      15
# x4       4      8       12      16      20
# x5       5     10       15      20      25
# x6       6     12       18      24      30
# x7       7     14       21      28      35
# x8       8     16       24      32      40
# x9       9     18       27      36      45

# %% [markdown]
# The following sorts the columns (`axis=1`) of the DataFrame in a descending order:

# %%
mt.sort_index(axis=1, ascending=False)
# Out:
#      byTwo  byThree  byOne  byFour  byFive
# x1       2        3      1       4       5
# x2       4        6      2       8      10
# x3       6        9      3      12      15
# x4       8       12      4      16      20
# x5      10       15      5      20      25
# x6      12       18      6      24      30
# x7      14       21      7      28      35
# x8      16       24      8      32      40
# x9      18       27      9      36      45
# x10     20       30     10      40      50

# %% [markdown]
# Here is how to sort the values a given a column

# %%
mt.sort_values('byThree', ascending=False)
# Out:
#      byOne  byTwo  byThree  byFour  byFive
# x10     10     20       30      40      50
# x9       9     18       27      36      45
# x8       8     16       24      32      40
# x7       7     14       21      28      35
# x6       6     12       18      24      30
# x5       5     10       15      20      25
# x4       4      8       12      16      20
# x3       3      6        9      12      15
# x2       2      4        6       8      10
# x1       1      2        3       4       5

# %% [markdown]
# and here is how to sort the values of a given row

# %%
mt.sort_values('x5', ascending=True, axis=1)
# Out:
#      byOne  byTwo  byThree  byFour  byFive
# x1       1      2        3       4       5
# x2       2      4        6       8      10
# x3       3      6        9      12      15
# x4       4      8       12      16      20
# x5       5     10       15      20      25
# x6       6     12       18      24      30
# x7       7     14       21      28      35
# x8       8     16       24      32      40
# x9       9     18       27      36      45
# x10     10     20       30      40      50

# %% [markdown]
# ## EXERCISE
#
# Recreate the 12 times table (see https://www.mathsisfun.com/tables.html) one column at a time. Start by creating an empty DataFrame representing the table. Use a series object to create the first column and add it to the table. Move on to the next column and do the same. And so on for the remaining columns. Use may use loops and expressions to calculate the values of these columns but no hard-coding of values and no code repetition.

# %%
import pandas as pd
import numpy as np
x=pd.Series(np.arange(1,13))
table = pd.DataFrame()
for i in range(1,13):
    table[i]=i*x
print("               12x12 Times Table:")
print(table)
